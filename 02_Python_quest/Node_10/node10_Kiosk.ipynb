# %%
# 프로젝트 1. 루브릭: 사각형 넓이 메소드

# %%
# 사각형 넓이를 구하는 클래스 완성!
class Square:
    def __init__(self):
        square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif square == 2:
            print('평행사변형 함수는 par()입니다.')

        elif square == 3:
            print('사다리꼴 함수는 trape()입니다.')

        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(',')) #가로, 세로를 입력받는 코드
        area = width * vertical # 넓이를 구하는 부분
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        width, vertical = map(int, input('밑변, 높이를 입력하세요. 예시 : 가로,세로\n >>>').split(','))  #가로, 세로를 입력받는 코드
        area = width * vertical  # 넓이를 구하는 부분
        result = '평행사변형의 넓이는 : ' + str(area) # [[YOUR CODE]]
        return result

    def trape(self):
        base, upper_base, height = map(int, input('밑변, 윗변, 높이를 입력하세요. 예시 : 밑변,윗변,높이\n >>>').split(','))  #밑변, 윗변, 높이를 입력받는 코드
        area = (base + upper_base) * height / 2  # 넓이를 구하는 부분
        result = '사다리꼴의 넓이는 : ' + str(area)
        return result

a = Square()  # 객체 생성 & 2, 3을 각각 입력해 봅시다.
a.trape()
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>>3
# 사다리꼴 함수는 trape()입니다.
# 밑변, 윗변, 높이를 입력하세요. 예시 : 밑변,윗변,높이
#  >>>3,2,1
# '사다리꼴의 넓이는 : 2.5'

# %%
#프로젝트 2. 루브릭: Kiosk 추가주문

# %%
# 문제 2-4. 추가 주문
# 추가 음료의 온도를 입력받고, 가격 리스트와 주문 리스트, 합계 금액을 업데이트합니다.

# 커피 메뉴와 가격
menu = ['americano', 'latte', 'mocha', 'yuza_tea', 'green_tea', 'choco_latte']
price = [2000, 3000, 3000, 2500, 2500, 3000]


class Kiosk:
    def __init__(self):
        self.menu = menu
        self.price = price

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i + 1, self.menu[i], ' : ', self.price[i], '원')


    def menu_select(self):
        self.order_menu = []  # 주문 리스트
        self.order_price = []  # 가격 리스트
        self.order_menu = []  # 주문한 메뉴들을 저장할 리스트
        self.order_price = []  # 주문한 메뉴의 가격을 저장할 리스트


        n = 0
        while n < 1 or len(menu) < n:
            n = int(input("음료를 번호를 입력하세요 : "))  # 음료 번호 입력

            # 메뉴판에 있는 음료 번호일 때
            if 1 <= n & n <= len(menu):
                self.order_price.append(self.price[n-1])  # 가격 리스트에 추가합니다.
                self.price_sum = self.price[n-1]  # 합계 금액

                # 메뉴판에 없는 번호일 때
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")


        # 음료 온도 물어보기
        t = 0  # 기본값을 넣어주고
        while t != 1 and t != 2:  # 1이나 2를 입력할 때까지 물어보기
            t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))
            # 문제 2-3의 답을 입력하세요.
            # [[YOUR CODE]]
            if t == 1:
                    self.temp = "HOT" # [[YOUR CODE]]
            elif t == 2:
                    self.temp = "ICE"
            else:
                print("1과 2 중 하나를 입력하세요.\n")

        self.order_menu.append(self.temp + ' ' + self.menu[n-1]) # 주문 리스트에 추가합니다.

        print(self.temp, '\n'+'주문 메뉴 : ', self.menu[n-1], ':',self.price[n-1], '원')  # 온도 속성을 추가한 주문 결과를 출력합니다.

        # 추가 주문 또는 지불
        while n != 0:  # 지불을 선택하기 전까지 반복합니다.
            print()  # 줄 바꾸면서
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))  # 추가 주문 또는 지불
            t=0
            if n > 0 and n < len(self.menu) + 1:
                # 추가 음료 온도
                t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))

                if t == 1:
                    self.temp = "HOT"
                elif t == 2:
                    self.temp = "ICE"
                else:
                    print("1과 2 중 하나를 입력하세요.\n")

                self.order_menu.append(self.temp + ' ' + self.menu[n-1])
                self.order_price.append(self.price[n-1])

                print(self.temp, '\n'+'주문 메뉴 : ', self.menu[n-1], ':',self.price[n-1], '원')
            else:
                if n == 0 :  # 지불을 입력하면
                    print("주문이 완료되었습니다.")
                    print(self.order_menu, self.order_price)  # 확인을 위한 리스트를 출력합니다.
                else:  # 없는 번호를 입력할 때
                    print("없는 메뉴입니다. 다시 주문해 주세요.")

#Kiosk.menu_select = menu_select

a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()
# Out:
# 1 americano  :  2000 원
# 2 latte  :  3000 원
# 3 mocha  :  3000 원
# 4 yuza_tea  :  2500 원
# 5 green_tea  :  2500 원
# 6 choco_latte  :  3000 원
# 음료를 번호를 입력하세요 : 1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# ICE
# 주문 메뉴 :  americano : 2000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# 주문이 완료되었습니다.
# ['ICE americano'] [2000]

# %%
# 프로젝트 3. 루브릭 : 키오스크 주문표까지

# %%
# 문제 3-3. 클래스 업데이트
# 앞에서 구현했던 메서드들을 Kiosk 클래스에 추가합니다. 직접 코드를 작성해 보세요!
menu = ['americano', 'latte', 'mocha', 'choco_latte']
price = [2000, 3000, 3000, 3000]

class Kiosk:
    def __init__(self):
        self.menu = menu
        self.price = price

    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ':', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        self.order_menu = []  # 주문 리스트
        self.order_price = []  # 가격 리스트
        self.order_menu = []  # 주문한 메뉴들을 저장할 리스트
        self.order_price = []  # 주문한 메뉴의 가격을 저장할 리스트

        n=0
        while n<1 or len(menu)<n:
            n = int(input("음료 번호를 입력 하세요: "))

            if 1<=n and n<= len(menu):
                self.order_price.append(self.price[n-1])
                self.price_a = self.price[n-1]

            else:
                ("없는 메뉴 입니다. 다시 주문해 주세요!")

        t=0
        while t != 1 and t != 2:
            t = int(input("Hot 음료는 1을, Ice는 2를 입력하세요: "))

            if t == 1:
                self.temp = 'Hot'
            elif t == 2:
                self.temp = 'Ice'
            else:
                print("1,2 중 입력 해주세요! \n")

        self.order_menu.append(self.temp + ' ' + self.menu[n-1])
        print(self.temp, '\n'+'주문메뉴: ',self.menu[n-1],':',self.price[n-1], '원')

        while n != 0:
            print()
            n = int(input("추가 주문은 음료 번호를, 지불은 0을 누르세요 : "))

            t=0
            if n > 0 and n < len(self.menu) + 1:
             # 추가 음료 온도
                t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))

                if t == 1:
                    self.temp = "HOT"
                elif t == 2:
                    self.temp = "ICE"
                else:
                    print("1과 2 중 하나를 입력하세요.\n")

            self.order_menu.append(self.temp + ' ' + self.menu[n-1])
            self.order_price.append(self.price[n-1])

            print(self.temp, '\n'+'주문 메뉴 : ', self.menu[n-1], ':',self.price[n-1], '원')
        else:
            if n == 0 :
                print("주문이 완료되었습니다.")
                print(self.order_menu, self.order_price)
            else:
                print("없는 메뉴입니다. 다시 주문해 주세요.")


    # 지불
    def pay(self):
        t = input("결제 방식을 선택해주세요 (현금: 'cash' or 1, 카드: 'card' or 2 )")

        while t != 1 and t != 2:

            if t == 'cash' or t == '1':
                print('직원을 호출하겠습니다.')
                break
            elif t == 'card' or t == '2':
                print('IC칩 방향에 맞게 카드를 꽂아주세요.')
                break
            elif t == 'end':
                print('거래가 완료되었습니다')
                break
            else:
                print('다시 결제를 시도해 주세요.')



    # 주문서 출력
    def table(self):
        print('⟝' + '-' * 30 + '⟞')

        for i in range(5):
            print('|' + ' ' * 31 + '|')

# 주문 상품명 : 해당 금액
        for i in range(len(menu)):
            print(menu[i], ' : ', price[i])

        print('합계 금액 :', sum(price))

# 외곽
        for i in range(5):
            print('|' + ' ' * 31+ '|')
        print('⟝' + '-' * 30 + '⟞')

a = Kiosk()  # 객체 생성
a.menu_print()  # 메뉴 출력
a.menu_select()  # 주문
a.pay()  # 지불
a.table()  # 주문표 출력
# Out:
# 1 americano : 2000 원
# 2 latte : 3000 원
# 3 mocha : 3000 원
# 4 choco_latte : 3000 원
# 음료 번호를 입력 하세요: 2
# Hot 음료는 1을, Ice는 2를 입력하세요: 1
# Hot
# 주문메뉴:  latte : 3000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 3
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 : 2
# ICE
# 주문 메뉴 :  mocha : 3000 원
#
# 추가 주문은 음료 번호를, 지불은 0을 누르세요 : 0
# ICE
# 주문 메뉴 :  choco_latte : 3000 원
# 주문이 완료되었습니다.
# ['Hot latte', 'ICE mocha', 'ICE choco_latte'] [3000, 3000, 3000]
# 결제 방식을 선택해주세요 (현금: 'cash' or 1, 카드: 'card' or 2 )1
# 직원을 호출하겠습니다.
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# americano  :  2000
# latte  :  3000
# mocha  :  3000
# choco_latte  :  3000
# 합계 금액 : 11000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
